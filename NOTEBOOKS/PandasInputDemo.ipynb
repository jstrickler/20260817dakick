# %% [markdown]
# # pandas Input Demo
#
# This notebook describes how to read data into pandas from various sources

# %% [markdown]
# ## standard imports

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## read_csv()
# Read CSV files. The delimiters and escaped characters can be tweaked as needed. There is a huge number of options for this function.

# %%
df_csv = pd.read_csv('../DATA/airport_boardings.csv', thousands=',', index_col=1)
df_csv.head()
# Out:
#                                                 Airport  2001 Rank  \
# Code
# ATL   Atlanta, GA (Hartsfield-Jackson Atlanta Intern...          1
# ORD          Chicago, IL (Chicago O'Hare International)          2
# DFW        Dallas, TX (Dallas/Fort Worth International)          3
# DEN                   Denver, CO (Denver International)          6
# LAX         Los Angeles, CA (Los Angeles International)          4
#
#       2001 Total  2010 Rank  2010 Total  2011 Rank     Total  \
# Code
# ATL     36384264          1    42655392          1  33034788
# ORD     28626694          2    30033313          2  22367052
# DFW     25198256          3    26785739          3  20430281
# DEN     16397390          4    24965553          4  19190341
# LAX     22873307          5    22860849          5  18379418
#
#       Percent change 2001-2011  Percent change 2010-2011
# Code
# ATL                       -9.2                     -22.6
# ORD                      -21.9                     -25.5
# DFW                      -18.9                     -23.7
# DEN                       17.0                     -23.1
# LAX                      -19.6                     -19.6

# %% [markdown]
# ## read_table()
# Read text files (other than CSV). This function is very similar to *read_csv()* and shares most of its options. This is the best choice for tab-delimited, space-delimited, and other delimited flat file formats.

# %%
df_table = pd.read_table('../DATA/columns_of_numbers.txt', sep=r"\s+")
df_table.set_index = pd.date_range('1/1/2017', periods=len(df_table), freq='D')
df_table.head()
# Out:
#    Alpha  Beta  Gamma  Delta  Epsilon  Zeta
# 0     63    51     59     61       50     4
# 1     40    66      9     64       63    17
# 2     18    23      2     61        1     9
# 3     29     8     40     59       10    26
# 4     54     9     68      4       16    21

# %%
df_table['Delta'].plot(kind='barh')
# Out:
# <Axes: >

# %%
df_table.plot(kind='scatter', x='Alpha', y='Zeta')
# Out:
# <Axes: xlabel='Alpha', ylabel='Zeta'>

# %% [markdown]
# ## read_sql(), read_sql_query(), read_sql_table()
# Read data from a SQL database. It requires a connection object from one of the Python modules that follows the DB API, or it can use a SQLAlchemy DB engine object. A dataframe is created from the rows in the result set.
#
# TODO: describe read_sql_table  read_sql_query

# %% [markdown]
# ### read_sql()
# read_sql() is a convenience function that delegates to either *read_sql_query()* or *read_sql_table()*, as appropriate.
# It takes a query (or a table name) and the database connection. If a table is specified, the connection must be a SQLAlchemy engine. If a query is specified, it can be either a SQLAlchemy engine or a DB API connection object, as from pymssql, pyodbc, pymysql, cx_oracle, psycopg, etc.

# %%
import sqlite3
conn = sqlite3.connect('../DATA/presidents.db')
# import psycopg2
# conn = psycopg2.connect(host='localhost', user='postgres', password='scripts')  
df_sql = pd.read_sql('select * from presidents', conn)
df_sql.head()
# Out:
#    termnum    lastname firstname   termstart     termend           birthplace  \
# 0        1  Washington    George  1789-04-30  1797-03-04  Westmoreland County
# 1        2       Adams      John  1797-03-04  1801-03-04   Braintree, Norfolk
# 2        3   Jefferson    Thomas  1801-03-04  1809-03-04    Albermarle County
# 3        4     Madison     James  1809-03-04  1817-03-04          Port Conway
# 4        5      Monroe     James  1817-03-04  1825-03-04  Westmoreland County
#
#       birthstate   birthdate   deathdate                    party
# 0       Virginia  1732-02-22  1799-12-14                 no party
# 1  Massachusetts  1735-10-30  1826-07-04               Federalist
# 2       Virginia  1743-04-13  1826-07-04  Democratic - Republican
# 3       Virginia  1751-03-16  1836-06-28  Democratic - Republican
# 4       Virginia  1758-04-28  1831-07-04  Democratic - Republican

# %% [markdown]
# ### read_sql_query()
# read_sql_query() populates a dataframe from a SQL query. Either a DB API connection or a SQLAlchemy engine may be specified.

# %%
df_sql = pd.read_sql_query('select * from presidents', conn)
df_sql.head()
# Out:
#    termnum    lastname firstname   termstart     termend           birthplace  \
# 0        1  Washington    George  1789-04-30  1797-03-04  Westmoreland County
# 1        2       Adams      John  1797-03-04  1801-03-04   Braintree, Norfolk
# 2        3   Jefferson    Thomas  1801-03-04  1809-03-04    Albermarle County
# 3        4     Madison     James  1809-03-04  1817-03-04          Port Conway
# 4        5      Monroe     James  1817-03-04  1825-03-04  Westmoreland County
#
#       birthstate   birthdate   deathdate                    party
# 0       Virginia  1732-02-22  1799-12-14                 no party
# 1  Massachusetts  1735-10-30  1826-07-04               Federalist
# 2       Virginia  1743-04-13  1826-07-04  Democratic - Republican
# 3       Virginia  1751-03-16  1836-06-28  Democratic - Republican
# 4       Virginia  1758-04-28  1831-07-04  Democratic - Republican

# %% [markdown]
# ### read_sql_table()
# read_sql_table() populates a dataframe with an entire SQL table. The connection must be a SQLAlchemy engine.

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///../DATA/presidents.db')
df_sql = pd.read_sql_table('presidents', engine)
df_sql.head()
# Out:
#    termnum    lastname firstname  termstart    termend           birthplace  \
# 0        1  Washington    George 1789-04-30 1797-03-04  Westmoreland County
# 1        2       Adams      John 1797-03-04 1801-03-04   Braintree, Norfolk
# 2        3   Jefferson    Thomas 1801-03-04 1809-03-04    Albermarle County
# 3        4     Madison     James 1809-03-04 1817-03-04          Port Conway
# 4        5      Monroe     James 1817-03-04 1825-03-04  Westmoreland County
#
#       birthstate  birthdate  deathdate                    party
# 0       Virginia 1732-02-22 1799-12-14                 no party
# 1  Massachusetts 1735-10-30 1826-07-04               Federalist
# 2       Virginia 1743-04-13 1826-07-04  Democratic - Republican
# 3       Virginia 1751-03-16 1836-06-28  Democratic - Republican
# 4       Virginia 1758-04-28 1831-07-04  Democratic - Republican

# %% [markdown]
# ## read_excel()
# Read data from an Excel spreadsheet. The spreadsheet may be on the local computer, or specified via a URL.
#
# <!-- TODO: use different spreadsheet for local -->

# %% [markdown]
# ### Local file

# %%
df_excel_local = pd.read_excel('../DATA/presidents.xlsx')
df_excel_local.head()
# Out:
#    Term   Last Name First Name  Birth Date  Death Date       Place of Birth  \
# 0     1  Washington     George  1732-02-22  1799-12-14  Westmoreland County
# 1     2       Adams       John  1735-10-30  1826-07-04   Braintree, Norfolk
# 2     3   Jefferson     Thomas  1743-04-13  1826-07-04    Albermarle County
# 3     4     Madison      James  1751-03-16  1836-06-28          Port Conway
# 4     5      Monroe      James  1758-04-28  1831-07-04  Westmoreland County
#
#   State of Birth Date took office Date left Office        Party affiliation
# 0       Virginia       1789-04-30       1797-03-04                 no party
# 1  Massachusetts       1797-03-04       1801-03-04               Federalist
# 2       Virginia       1801-03-04       1809-03-04  Democratic - Republican
# 3       Virginia       1809-03-04       1817-03-04  Democratic - Republican
# 4       Virginia       1817-03-04       1825-03-04  Democratic - Republican

# %% [markdown]
# ### URL

# %%
df_excel_url = pd.read_excel('http://qrc.depaul.edu/Excel_Files/Presidents.xlsx',
        na_values="NA()")
df_excel_url.head()
# Out:
#            President  Years in office  Year first inaugurated  \
# 0  George Washington              8.0                    1789
# 1         John Adams              4.0                    1797
# 2   Thomas Jefferson              8.0                    1801
# 3      James Madison              8.0                    1809
# 4       James Monroe              8.0                    1817
#
#    Age at inauguration State elected from  # of electoral votes  \
# 0                   57           Virginia                    69
# 1                   61      Massachusetts                   132
# 2                   57           Virginia                    73
# 3                   57           Virginia                   122
# 4                   58           Virginia                   183
#
#    # of popular votes  National total votes  Total electoral votes  \
# 0                 NaN                   NaN                     69
# 1                 NaN                   NaN                    139
# 2                 NaN                   NaN                    137
# 3                 NaN                   NaN                    176
# 4                 NaN                   NaN                    221
#
#    Rating points        Political Party       Occupation           College  \
# 0          842.0                    NaN          Planter               NaN
# 1          598.0             Federalist           Lawyer           Harvard
# 2          711.0  Democratic-Republican  Planter, Lawyer  William and Mary
# 3          567.0  Democratic-Republican           Lawyer         Princeton
# 4          602.0  Democratic-Republican           Lawyer  William and Mary
#
#    % electoral  % popular
# 0   100.000000        NaN
# 1    94.964029        NaN
# 2    53.284672        NaN
# 3    69.318182        NaN
# 4    82.805430        NaN

# %% [markdown]
# ## read_html()
# Read data from one or more tables in a Web page. It returns a list of DataFrames, even if there is only one table in the page.
#
# The example uses a table from SimilarWeb.com that shows the most commonly visited websites.

# %%
df_list = pd.read_html(
    'https://www.similarweb.com/top-websites/', 
    header=0,
    converters={'Bounce Rate': lambda br: float(br.removesuffix('%'))},
)
    
df_sites = df_list[0]
df_sites.rename(columns={'Bounce Rate': 'Bounce Rate %'}, inplace=True)
df_sites
# Out:
#     Rank            Website  \
# 0      1         google.com
# 1      2        youtube.com
# 2      3       facebook.com
# 3      4      instagram.com
# 4      5        chatgpt.com
# 5      6              x.com
# 6      7         reddit.com
# 7      8           bing.com
# 8      9         tiktok.com
# 9     10       whatsapp.com
# 10    11      wikipedia.org
# 11    12        yahoo.co.jp
# 12    13          yahoo.com
# 13    14          yandex.ru
# 14    15         amazon.com
# 15    16  gemini.google.com
# 16    17       linkedin.com
# 17    18          baidu.com
# 18    19          naver.com
# 19    20        netflix.com
# 20    21      pinterest.com
# 21    22             bet.br
# 22    23           live.com
# 23    24        pornhub.com
# 24    25    cloud.microsoft
# 25    26       bilibili.com
# 26    27       xhamster.com
# 27    28            dzen.ru
# 28    29        weather.com
# 29    30          twitch.tv
# 30    31           temu.com
# 31    32      microsoft.com
# 32    33          claude.ai
# 33    34        xvideos.com
# 34    35        samsung.com
# 35    36         fandom.com
# 36    37          canva.com
# 37    38   news.yahoo.co.jp
# 38    39            mail.ru
# 39    40          globo.com
# 40    41     duckduckgo.com
# 41    42        booking.com
# 42    43      stripchat.com
# 43    44               t.me
# 44    45           ebay.com
# 45    46        discord.com
# 46    47          brave.com
# 47    48           imdb.com
# 48    49          bbc.co.uk
# 49    50         github.com
#
#                                              Category Rank Change  \
# 0   Computers Electronics and Technology > Search ...           =
# 1        Arts & Entertainment > Streaming & Online TV           =
# 2   Computers Electronics and Technology > Social ...           =
# 3   Computers Electronics and Technology > Social ...           =
# 4                               AI Chatbots and Tools           =
# 5   Computers Electronics and Technology > Social ...           =
# 6   Computers Electronics and Technology > Social ...           =
# 7   Computers Electronics and Technology > Search ...           1
# 8   Computers Electronics and Technology > Social ...           1
# 9   Computers Electronics and Technology > Social ...           2
# 10  Reference Materials > Dictionaries and Encyclo...           =
# 11                            News & Media Publishers           1
# 12                            News & Media Publishers           1
# 13  Computers Electronics and Technology > Search ...           1
# 14                 Ecommerce & Shopping > Marketplace           1
# 15                              AI Chatbots and Tools           4
# 16  Computers Electronics and Technology > Social ...           =
# 17  Computers Electronics and Technology > Search ...           =
# 18  Computers Electronics and Technology > Search ...           1
# 19       Arts & Entertainment > Streaming & Online TV           2
# 20  Computers Electronics and Technology > Social ...           =
# 21                          Gambling > Sports Betting           3
# 22       Computers Electronics and Technology > Email           1
# 23                                              Adult           1
# 24  Computers Electronics and Technology > Program...           2
# 25        Arts & Entertainment > Animation and Comics           1
# 26                                              Adult           1
# 27  Community and Society > Community and Society ...           1
# 28                    Science and Education > Weather           1
# 29       Games > Video Games Consoles and Accessories           2
# 30                 Ecommerce & Shopping > Marketplace           3
# 31  Computers Electronics and Technology > Program...           1
# 32                              AI Chatbots and Tools           1
# 33                                              Adult           1
# 34  Computers Electronics and Technology > Consume...           6
# 35  Arts & Entertainment > Arts and Entertainment ...           2
# 36  Computers Electronics and Technology > Graphic...           1
# 37                            News & Media Publishers           1
# 38       Computers Electronics and Technology > Email           1
# 39                            News & Media Publishers           1
# 40  Computers Electronics and Technology > Search ...           1
# 41      Travel and Tourism > Accommodation and Hotels           8
# 42                                              Adult           1
# 43  Computers Electronics and Technology > Compute...           1
# 44                 Ecommerce & Shopping > Marketplace           2
# 45  Computers Electronics and Technology > Social ...           =
# 46  Computers Electronics and Technology > Compute...           2
# 47       Arts & Entertainment > Streaming & Online TV           6
# 48                            News & Media Publishers           4
# 49  Computers Electronics and Technology > Program...           2
#
#    Avg. Visit Duration  Pages / Visit  Bounce Rate %
# 0             00:09:58           8.68          28.49
# 1             00:19:05          11.81          23.26
# 2             00:10:22          12.37          29.85
# 3             00:08:33          12.55          33.52
# 4             00:06:35           4.29          29.51
# 5             00:12:15          14.31          32.38
# 6             00:05:51           4.84          42.88
# 7             00:07:18           6.19          33.80
# 8             00:05:19           9.32          42.80
# 9             00:09:30           3.58          62.14
# 10            00:03:16           3.35          53.39
# 11            00:08:38           7.29          33.47
# 12            00:06:09           4.94          38.69
# 13            00:07:45           8.36          28.30
# 14            00:05:52           9.18          30.57
# 15            00:07:01           4.13          27.80
# 16            00:07:11           8.93          22.07
# 17            00:04:42           8.76          25.19
# 18            00:12:44          11.57          27.56
# 19            00:06:23           4.27          39.12
# 20            00:07:08           7.57          35.86
# 21            00:12:06          12.53          29.98
# 22            00:06:13           6.91          24.50
# 23            00:07:19           7.30          26.46
# 24            00:12:38           8.43          23.85
# 25            00:18:22          13.14          15.00
# 26            00:09:01           7.85          26.62
# 27            00:07:32           5.64          32.92
# 28            00:01:05           2.01          47.19
# 29            00:07:59           4.73          31.44
# 30            00:04:13           4.70          44.68
# 31            00:02:55           3.50          45.46
# 32            00:06:14           4.47          25.54
# 33            00:09:52           9.01          25.30
# 34            00:01:43           2.58          38.87
# 35            00:04:28           4.33          49.49
# 36            00:05:59           6.46          26.65
# 37            00:06:37           4.97          27.64
# 38            00:06:38           8.88          36.08
# 39            00:02:55           2.13          51.70
# 40            00:07:14           6.18          15.40
# 41            00:07:41           8.33          25.82
# 42            00:06:24           7.25          34.10
# 43            00:02:28           2.50          63.31
# 44            00:06:07           6.75          38.55
# 45            00:11:13           9.51          32.38
# 46            00:04:17           4.30          29.79
# 47            00:02:36           4.45          35.59
# 48            00:04:16           3.08          45.08
# 49            00:06:26           5.87          36.27

# %% [markdown]
# ## read_fwf()
# This function reads files with fixed-width fields. If the fields you want are contiguous, specify the widths of all columns with the *widths* parameter. If they are non-contiguous (you just want to pull out certain columns), specify the columns with the *colspecs* parameter, which takes a list of tuples describing the beginning and end end of each desired column. If neither *widths* or *colspecs* is given, *read_fwf()* tries to infer the columns.

# %%
df_fwf = pd.read_fwf('../DATA/world_median_ages.txt', 
    names=['country', 'median_age'], widths=[7,50,4], index_col=0)
print(df_fwf.head())
print(df_fwf.iloc[1])
# Out:
#                      country  median_age
# 1                     Monaco        52.0
# 2                      Japan        46.0
# 3                    Germany        46.0
# 4  Saint Pierre and Miquelon        45.0
# 5             Virgin Islands        45.0
# country       Japan
# median_age     46.0
# Name: 2, dtype: object

# %%
ax = df_fwf.iloc[:20].plot(kind='barh', x='country', y='median_age')
print(type(ax))
ax.set_ylabel('Median Age')
# Out:
# <class 'matplotlib.axes._axes.Axes'>
# Text(0, 0.5, 'Median Age')
